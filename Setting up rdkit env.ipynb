# %% [markdown]
# ## For work with RDKit the following comands were executed:
#
# 1. Create separate environment for rdkit`conda create -n rdkit`
# 2. Activate created environment `conda activate rdkit`
# 3. Install pip to the rdkit environment `conda install pip`
# 4. Update conda in base environment (that was requested by conda itself) `conda update -n base -c defaults conda` : \
#     `EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: /opt/conda
#   uid: 73944
#   gid: 60000` \
#   Comment: installation 4 haven't succeeded
# 5. `pip install cgrtools` - requirement from the Practical Exercises Book
# 6. `pip install cimtools` - 2nd requirement from the Practical Exercises Book \
#     `Getting requirements to build wheel ... error \
#   error: subprocess-exited-with-error \
#
#   × Getting requirements to build wheel did not run successfully. \
#   │ exit code: 1 \
#   ╰─> [21 lines of output] \
#       Traceback (most recent call last): \
#         File "/home/47b38227-ee56-490a-ae8b-a925a4f4b307/.conda/envs/rdkit/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module> \
#           main() \
#         File "/home/47b38227-ee56-490a-ae8b-a925a4f4b307/.conda/envs/rdkit/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main \
#           json_out['return_val'] = hook(**hook_input['kwargs']) \
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^ \
#         File "/home/47b38227-ee56-490a-ae8b-a925a4f4b307/.conda/envs/rdkit/lib/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel \
#           return hook(config_settings) \
#                  ^^^^^^^^^^^^^^^^^^^^^ \
#         File "/tmp/pip-build-env-ud_whe86/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 338, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=['wheel']) \
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ \
#         File "/tmp/pip-build-env-ud_whe86/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 320, in _get_build_requires
#           self.run_setup() \
#         File "/tmp/pip-build-env-ud_whe86/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 485, in run_setup
#           self).run_setup(setup_script=setup_script) \
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ \
#         File "/tmp/pip-build-env-ud_whe86/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 335, in run_setup \
#           exec(code, locals()) \
#         File "<string>", line 70, in <module> \
#       AssertionError: You need a JDK, we only found a JRE. Try setting JAVA_HOME \
#       [end of output] \`
#
#     Fixing cimtools installation:
#     1. conda install -c bioconda java-jdk
#     2. export JAVA_HOME=$(readlink -f /usr/bin/javac | sed "s:/bin/javac::")
#     3. retry `pip install cimtools`
#     installation succeeded
#
# 7. `conda install ipykernel` for actually being able to choose the kernel of a created environment

# %%
import sys
print(sys.executable)
# Out:
# /home/47b38227-ee56-490a-ae8b-a925a4f4b307/.conda/envs/rdkit/bin/python
